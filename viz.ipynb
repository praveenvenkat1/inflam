# %%
filename = "data/small-01.csv"

# %%
from inflammation import models, views

# %%
inflammation_data = models.load_csv(filename)
view_data = {'average': models.daily_mean(inflammation_data), 'max': models.daily_max(inflammation_data), 'min': models.daily_min(inflammation_data)}
views.visualize(view_data)

# %%
filename2 = "data/inflammation-02.csv"

# %%
inflammation_data2 = models.load_csv(filename2)
view_data2 = {'average': models.daily_mean(inflammation_data2), 'max': models.daily_max(inflammation_data2), 'min': models.daily_min(inflammation_data2)}
views.visualize(view_data2)
